# %%
import json
import requests

# Load Shopify credentials
with open("config.json", "r") as f:
    config = json.load(f)

SHOPIFY_STORE = config["shopify_store"]
API_KEY = config["api_key"]
PASSWORD = config["password"]

# Use the latest API version dynamically
SHOPIFY_API_VERSION = "2024-01"  # Update as needed
SHOPIFY_API_URL = f"https://{SHOPIFY_STORE}.myshopify.com/admin/api/{SHOPIFY_API_VERSION}/orders.json"

def fetch_shopify_orders():
    """Fetch sample orders from Shopify API and print response."""
    response = requests.get(SHOPIFY_API_URL, params={"status": "any", "limit": 5}, auth=(API_KEY, PASSWORD))
    
    if response.status_code != 200:
        print(f"Error: {response.status_code}, {response.text}")
        return []

    orders = response.json().get("orders", [])
    print(json.dumps(orders, indent=4))  # Pretty print sample data

fetch_shopify_orders()
# Out:
# [
#     {
#         "id": 6002412257506,
#         "admin_graphql_api_id": "gid://shopify/Order/6002412257506",
#         "app_id": 580111,
#         "browser_ip": "172.56.179.126",
#         "buyer_accepts_marketing": true,
#         "cancel_reason": null,
#         "cancelled_at": null,
#         "cart_token": "Z2NwLXVzLXdlc3QxOjAxSk1KNTgxR1lCM1dRNEo4QVFGRVZSNkgy",
#         "checkout_id": 35677846601954,
#         "checkout_token": "b196101e74ae5c56567a12094ff992f6",
#         "client_details": {
#             "accept_language": "en-US",
#             "browser_height": null,
#             "browser_ip": "172.56.179.126",
#             "browser_width": null,
#             "session_hash": null,
#             "user_agent": "Mozilla/5.0 (Linux; Android 10; K) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Mobile Safari/537.36"
#         },
#         "closed_at": null,
#         "confirmation_number": "JKEY5AWXP",
#         "confirmed": true,
#         "contact_email": "sportdad4life@yahoo.com",
#         "created_at": "2025-02-20T09:19:23-08:00",
#         "currency": "USD",
#         "current_subtotal_price": "41.00",
#         "current_subtotal_price_set": {
#             "shop_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_additional_fees_set": null,
#         "current_total_discounts": "0.00",
#         "current_total_discounts_set": {
#             "shop_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_duties_set": null,
#         "current_total_price": "48.63",
#         "current_total_price_set": {
#             "shop_money": {
#                 "amount": "48.63",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "48.63",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_tax": "3.19",
#         "current_total_tax_set": {
#             "shop_money": {
#                 "amount": "3.19",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "3.19",
#                 "currency_code": "USD"
#             }
#         },
#         "customer_locale": "en-US",
#         "device_id": null,
#         "discount_codes": [],
#         "email": "sportdad4life@yahoo.com",
#         "estimated_taxes": false,
#         "financial_status": "paid",
#         "fulfillment_status": null,
#         "landing_site": "/?srsltid=AfmBOoqcT_n5Q4IAcmRaetZ2ugwksyCdyZ1KRbRboFK2KvdERGgQ4j3y",
#         "landing_site_ref": null,
#         "location_id": null,
#         "merchant_of_record_app_id": null,
#         "name": "#13328",
#         "note": null,
#         "note_attributes": [],
#         "number": 12328,
#         "order_number": 13328,
#         "order_status_url": "https://catchamerica.com/72834777314/orders/34a2a8a03e4d1935b527ce2e70b5f478/authenticate?key=1446239b2d78e28bc8cb68e3779627f1",
#         "original_total_additional_fees_set": null,
#         "original_total_duties_set": null,
#         "payment_gateway_names": [
#             "shopify_payments"
#         ],
#         "phone": null,
#         "po_number": null,
#         "presentment_currency": "USD",
#         "processed_at": "2025-02-20T09:19:21-08:00",
#         "reference": null,
#         "referring_site": "https://www.google.com/",
#         "source_identifier": null,
#         "source_name": "web",
#         "source_url": null,
#         "subtotal_price": "41.00",
#         "subtotal_price_set": {
#             "shop_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             }
#         },
#         "tags": "",
#         "tax_exempt": false,
#         "tax_lines": [
#             {
#                 "price": "0.11",
#                 "rate": 0.0025,
#                 "title": "Fresno County Tax",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "0.11",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.11",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "0.21",
#                 "rate": 0.005,
#                 "title": "San Bernardino County District Tax Sp",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "0.21",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.21",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "0.41",
#                 "rate": 0.01,
#                 "title": "Fresno Co Local Tax Sl",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "0.41",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.41",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "2.46",
#                 "rate": 0.06,
#                 "title": "California State Tax",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "2.46",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "2.46",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             }
#         ],
#         "taxes_included": false,
#         "test": false,
#         "token": "34a2a8a03e4d1935b527ce2e70b5f478",
#         "total_discounts": "0.00",
#         "total_discounts_set": {
#             "shop_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             }
#         },
#         "total_line_items_price": "41.00",
#         "total_line_items_price_set": {
#             "shop_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "41.00",
#                 "currency_code": "USD"
#             }
#         },
#         "total_outstanding": "0.00",
#         "total_price": "48.63",
#         "total_price_set": {
#             "shop_money": {
#                 "amount": "48.63",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "48.63",
#                 "currency_code": "USD"
#             }
#         },
#         "total_shipping_price_set": {
#             "shop_money": {
#                 "amount": "4.44",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "4.44",
#                 "currency_code": "USD"
#             }
#         },
#         "total_tax": "3.19",
#         "total_tax_set": {
#             "shop_money": {
#                 "amount": "3.19",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "3.19",
#                 "currency_code": "USD"
#             }
#         },
#         "total_tip_received": "0.00",
#         "total_weight": 0,
#         "updated_at": "2025-02-20T09:19:25-08:00",
#         "user_id": null,
#         "billing_address": {
#             "first_name": "Adrian",
#             "address1": "13874 Fontainbleau Lane",
#             "phone": "18188224725",
#             "city": "Chino Hills",
#             "zip": "91709",
#             "province": "California",
#             "country": "United States",
#             "last_name": "Gutierrez",
#             "address2": null,
#             "company": null,
#             "latitude": null,
#             "longitude": null,
#             "name": "Adrian Gutierrez",
#             "country_code": "US",
#             "province_code": "CA"
#         },
#         "customer": {
#             "id": 7925030879458,
#             "email": "sportdad4life@yahoo.com",
#             "created_at": "2025-02-20T09:19:21-08:00",
#             "updated_at": "2025-02-20T09:19:29-08:00",
#             "first_name": "Adrian",
#             "last_name": "Gutierrez",
#             "state": "disabled",
#             "note": null,
#             "verified_email": true,
#             "multipass_identifier": null,
#             "tax_exempt": false,
#             "phone": null,
#             "email_marketing_consent": {
#                 "state": "subscribed",
#                 "opt_in_level": "single_opt_in",
#                 "consent_updated_at": "2025-02-20T09:19:24-08:00"
#             },
#             "sms_marketing_consent": null,
#             "tags": "",
#             "currency": "USD",
#             "tax_exemptions": [],
#             "admin_graphql_api_id": "gid://shopify/Customer/7925030879458",
#             "default_address": {
#                 "id": 9436685107426,
#                 "customer_id": 7925030879458,
#                 "first_name": "Adrian",
#                 "last_name": "Gutierrez",
#                 "company": null,
#                 "address1": "13874 Fontainbleau Lane",
#                 "address2": null,
#                 "city": "Chino Hills",
#                 "province": "California",
#                 "country": "United States",
#                 "zip": "91709",
#                 "phone": "18188224725",
#                 "name": "Adrian Gutierrez",
#                 "province_code": "CA",
#                 "country_code": "US",
#                 "country_name": "United States",
#                 "default": true
#             }
#         },
#         "discount_applications": [],
#         "fulfillments": [],
#         "line_items": [
#             {
#                 "id": 14577930404066,
#                 "admin_graphql_api_id": "gid://shopify/LineItem/14577930404066",
#                 "attributed_staffs": [],
#                 "current_quantity": 2,
#                 "fulfillable_quantity": 2,
#                 "fulfillment_service": "manual",
#                 "fulfillment_status": null,
#                 "gift_card": false,
#                 "grams": 0,
#                 "name": "Trix Rigging Kit",
#                 "pre_tax_price": "11.00",
#                 "pre_tax_price_set": {
#                     "shop_money": {
#                         "amount": "11.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "11.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "price": "5.50",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "5.50",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "5.50",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "product_exists": true,
#                 "product_id": 8788626440418,
#                 "properties": [],
#                 "quantity": 2,
#                 "requires_shipping": true,
#                 "sku": "",
#                 "taxable": true,
#                 "title": "Trix Rigging Kit",
#                 "total_discount": "0.00",
#                 "total_discount_set": {
#                     "shop_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "variant_id": 46249009512674,
#                 "variant_inventory_management": "shopify",
#                 "variant_title": null,
#                 "vendor": "Catch America",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.03",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.03",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.03",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.06",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.06",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.06",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.005,
#                         "title": "San Bernardino County District Tax Sp"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.11",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.11",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.11",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.66",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.66",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.66",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "duties": [],
#                 "discount_allocations": []
#             },
#             {
#                 "id": 14577930436834,
#                 "admin_graphql_api_id": "gid://shopify/LineItem/14577930436834",
#                 "attributed_staffs": [],
#                 "current_quantity": 2,
#                 "fulfillable_quantity": 2,
#                 "fulfillment_service": "manual",
#                 "fulfillment_status": null,
#                 "gift_card": false,
#                 "grams": 0,
#                 "name": "Trout Trix Worms Kit",
#                 "pre_tax_price": "30.00",
#                 "pre_tax_price_set": {
#                     "shop_money": {
#                         "amount": "30.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "30.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "price": "15.00",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "15.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "15.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "product_exists": true,
#                 "product_id": 8788658585826,
#                 "properties": [],
#                 "quantity": 2,
#                 "requires_shipping": true,
#                 "sku": "",
#                 "taxable": true,
#                 "title": "Trout Trix Worms Kit",
#                 "total_discount": "0.00",
#                 "total_discount_set": {
#                     "shop_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "variant_id": 46249130328290,
#                 "variant_inventory_management": "shopify",
#                 "variant_title": null,
#                 "vendor": "Catch America",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.08",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.08",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.08",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.15",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.15",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.15",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.005,
#                         "title": "San Bernardino County District Tax Sp"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.30",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.30",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.30",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "1.80",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "1.80",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "1.80",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "duties": [],
#                 "discount_allocations": []
#             }
#         ],
#         "payment_terms": null,
#         "refunds": [],
#         "shipping_address": {
#             "first_name": "Adrian",
#             "address1": "13874 Fontainbleau Lane",
#             "phone": "18188224725",
#             "city": "Chino Hills",
#             "zip": "91709",
#             "province": "California",
#             "country": "United States",
#             "last_name": "Gutierrez",
#             "address2": null,
#             "company": null,
#             "latitude": 34.00077820000001,
#             "longitude": -117.7355848,
#             "name": "Adrian Gutierrez",
#             "country_code": "US",
#             "province_code": "CA"
#         },
#         "shipping_lines": [
#             {
#                 "id": 4873520218338,
#                 "carrier_identifier": null,
#                 "code": "GroundAdvantage",
#                 "discounted_price": "4.44",
#                 "discounted_price_set": {
#                     "shop_money": {
#                         "amount": "4.44",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "4.44",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "is_removed": false,
#                 "phone": null,
#                 "price": "4.44",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "4.44",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "4.44",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "requested_fulfillment_service_id": null,
#                 "source": "usps",
#                 "title": "Ground Advantage",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.005,
#                         "title": "San Bernardino County District Tax Sp"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "discount_allocations": []
#             }
#         ]
#     },
#     {
#         "id": 6002019369186,
#         "admin_graphql_api_id": "gid://shopify/Order/6002019369186",
#         "app_id": 580111,
#         "browser_ip": "2601:648:4200:95b0:750c:14a6:7df5:7238",
#         "buyer_accepts_marketing": true,
#         "cancel_reason": null,
#         "cancelled_at": null,
#         "cart_token": "Z2NwLXVzLXdlc3QxOjAxSk1IQlBUWjNISEQ4VjRSUkc2Q1dLRVNR",
#         "checkout_id": 35676923560162,
#         "checkout_token": "c89a4f145d612bfa9410a80dda64e811",
#         "client_details": {
#             "accept_language": "en-US",
#             "browser_height": null,
#             "browser_ip": "2601:648:4200:95b0:750c:14a6:7df5:7238",
#             "browser_width": null,
#             "session_hash": null,
#             "user_agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.6 Mobile/15E148 Safari/604.1"
#         },
#         "closed_at": "2025-02-20T07:29:12-08:00",
#         "confirmation_number": "CUK5WZXAE",
#         "confirmed": true,
#         "contact_email": "rdemarta@comcast.net",
#         "created_at": "2025-02-20T02:02:31-08:00",
#         "currency": "USD",
#         "current_subtotal_price": "115.33",
#         "current_subtotal_price_set": {
#             "shop_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_additional_fees_set": null,
#         "current_total_discounts": "0.00",
#         "current_total_discounts_set": {
#             "shop_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_duties_set": null,
#         "current_total_price": "124.41",
#         "current_total_price_set": {
#             "shop_money": {
#                 "amount": "124.41",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "124.41",
#                 "currency_code": "USD"
#             }
#         },
#         "current_total_tax": "9.08",
#         "current_total_tax_set": {
#             "shop_money": {
#                 "amount": "9.08",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "9.08",
#                 "currency_code": "USD"
#             }
#         },
#         "customer_locale": "en-US",
#         "device_id": null,
#         "discount_codes": [],
#         "email": "rdemarta@comcast.net",
#         "estimated_taxes": false,
#         "financial_status": "paid",
#         "fulfillment_status": "fulfilled",
#         "landing_site": "/?srsltid=AfmBOoqgwTCm2N_r8DF2ty4rQsFknH71yqeDxapSl3P-ZeFYqx76OBkZ",
#         "landing_site_ref": null,
#         "location_id": null,
#         "merchant_of_record_app_id": null,
#         "name": "#13327",
#         "note": null,
#         "note_attributes": [],
#         "number": 12327,
#         "order_number": 13327,
#         "order_status_url": "https://catchamerica.com/72834777314/orders/c703129e7694aba3228e12e580eaaa07/authenticate?key=f95cf03a20f72a05786fd8b6d5e87e02",
#         "original_total_additional_fees_set": null,
#         "original_total_duties_set": null,
#         "payment_gateway_names": [
#             "shopify_payments"
#         ],
#         "phone": null,
#         "po_number": null,
#         "presentment_currency": "USD",
#         "processed_at": "2025-02-20T02:02:19-08:00",
#         "reference": null,
#         "referring_site": "https://catchamerica.com/",
#         "source_identifier": null,
#         "source_name": "web",
#         "source_url": null,
#         "subtotal_price": "115.33",
#         "subtotal_price_set": {
#             "shop_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             }
#         },
#         "tags": "",
#         "tax_exempt": false,
#         "tax_lines": [
#             {
#                 "price": "6.92",
#                 "rate": 0.06,
#                 "title": "California State Tax",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "6.92",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "6.92",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "0.29",
#                 "rate": 0.0025,
#                 "title": "Fresno County Tax",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "0.29",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.29",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "0.71",
#                 "rate": 0.00625,
#                 "title": "Mendocino County District Tax Sp",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "0.71",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.71",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             },
#             {
#                 "price": "1.16",
#                 "rate": 0.01,
#                 "title": "Fresno Co Local Tax Sl",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "1.16",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "1.16",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "channel_liable": false
#             }
#         ],
#         "taxes_included": false,
#         "test": false,
#         "token": "c703129e7694aba3228e12e580eaaa07",
#         "total_discounts": "0.00",
#         "total_discounts_set": {
#             "shop_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             }
#         },
#         "total_line_items_price": "115.33",
#         "total_line_items_price_set": {
#             "shop_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "115.33",
#                 "currency_code": "USD"
#             }
#         },
#         "total_outstanding": "0.00",
#         "total_price": "124.41",
#         "total_price_set": {
#             "shop_money": {
#                 "amount": "124.41",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "124.41",
#                 "currency_code": "USD"
#             }
#         },
#         "total_shipping_price_set": {
#             "shop_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "0.00",
#                 "currency_code": "USD"
#             }
#         },
#         "total_tax": "9.08",
#         "total_tax_set": {
#             "shop_money": {
#                 "amount": "9.08",
#                 "currency_code": "USD"
#             },
#             "presentment_money": {
#                 "amount": "9.08",
#                 "currency_code": "USD"
#             }
#         },
#         "total_tip_received": "0.00",
#         "total_weight": 2722,
#         "updated_at": "2025-02-20T07:29:12-08:00",
#         "user_id": null,
#         "billing_address": {
#             "first_name": "Ryan",
#             "address1": "1520 Road D",
#             "phone": "+17073188529",
#             "city": "Redwood Valley",
#             "zip": "95470",
#             "province": "California",
#             "country": "United States",
#             "last_name": "Demarta",
#             "address2": null,
#             "company": null,
#             "latitude": null,
#             "longitude": null,
#             "name": "Ryan Demarta",
#             "country_code": "US",
#             "province_code": "CA"
#         },
#         "customer": {
#             "id": 7924655259874,
#             "email": "rdemarta@comcast.net",
#             "created_at": "2025-02-20T01:40:42-08:00",
#             "updated_at": "2025-02-20T02:02:32-08:00",
#             "first_name": "Ryan",
#             "last_name": "Demarta",
#             "state": "disabled",
#             "note": null,
#             "verified_email": true,
#             "multipass_identifier": null,
#             "tax_exempt": false,
#             "phone": null,
#             "email_marketing_consent": {
#                 "state": "subscribed",
#                 "opt_in_level": "single_opt_in",
#                 "consent_updated_at": "2025-02-20T01:40:42-08:00"
#             },
#             "sms_marketing_consent": null,
#             "tags": "newsletter",
#             "currency": "USD",
#             "tax_exemptions": [],
#             "admin_graphql_api_id": "gid://shopify/Customer/7924655259874",
#             "default_address": {
#                 "id": 9436330721506,
#                 "customer_id": 7924655259874,
#                 "first_name": "Ryan",
#                 "last_name": "Demarta",
#                 "company": null,
#                 "address1": "1520 Road D",
#                 "address2": null,
#                 "city": "Redwood Valley",
#                 "province": "California",
#                 "country": "United States",
#                 "zip": "95470",
#                 "phone": "+17073188529",
#                 "name": "Ryan Demarta",
#                 "province_code": "CA",
#                 "country_code": "US",
#                 "country_name": "United States",
#                 "default": true
#             }
#         },
#         "discount_applications": [],
#         "fulfillments": [
#             {
#                 "id": 5416926019810,
#                 "admin_graphql_api_id": "gid://shopify/Fulfillment/5416926019810",
#                 "created_at": "2025-02-20T07:29:12-08:00",
#                 "location_id": 79554609378,
#                 "name": "#13327.1",
#                 "order_id": 6002019369186,
#                 "origin_address": {},
#                 "receipt": {},
#                 "service": "manual",
#                 "shipment_status": null,
#                 "status": "success",
#                 "tracking_company": "USPS",
#                 "tracking_number": "420954709334610597204060782114",
#                 "tracking_numbers": [
#                     "420954709334610597204060782114"
#                 ],
#                 "tracking_url": "https://tools.usps.com/go/TrackConfirmAction_input?qtc_tLabels1=420954709334610597204060782114",
#                 "tracking_urls": [
#                     "https://tools.usps.com/go/TrackConfirmAction_input?qtc_tLabels1=420954709334610597204060782114"
#                 ],
#                 "updated_at": "2025-02-20T07:29:12-08:00",
#                 "line_items": [
#                     {
#                         "id": 14577224876258,
#                         "admin_graphql_api_id": "gid://shopify/LineItem/14577224876258",
#                         "attributed_staffs": [],
#                         "current_quantity": 1,
#                         "fulfillable_quantity": 0,
#                         "fulfillment_service": "manual",
#                         "fulfillment_status": "fulfilled",
#                         "gift_card": false,
#                         "grams": 0,
#                         "name": "Trigger Scent by Cal Kellogg",
#                         "pre_tax_price": "9.00",
#                         "pre_tax_price_set": {
#                             "shop_money": {
#                                 "amount": "9.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "9.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "price": "9.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "9.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "9.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "product_exists": true,
#                         "product_id": 8795040350434,
#                         "properties": [],
#                         "quantity": 1,
#                         "requires_shipping": true,
#                         "sku": "",
#                         "taxable": true,
#                         "title": "Trigger Scent by Cal Kellogg",
#                         "total_discount": "0.00",
#                         "total_discount_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "variant_id": 46265682198754,
#                         "variant_inventory_management": "shopify",
#                         "variant_title": null,
#                         "vendor": "Catch America",
#                         "tax_lines": [
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.54",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.54",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.54",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.06,
#                                 "title": "California State Tax"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.02",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.02",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.02",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.0025,
#                                 "title": "Fresno County Tax"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.06",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.06",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.06",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.00625,
#                                 "title": "Mendocino County District Tax Sp"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.09",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.09",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.09",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.01,
#                                 "title": "Fresno Co Local Tax Sl"
#                             }
#                         ],
#                         "duties": [],
#                         "discount_allocations": []
#                     },
#                     {
#                         "id": 14577224909026,
#                         "admin_graphql_api_id": "gid://shopify/LineItem/14577224909026",
#                         "attributed_staffs": [],
#                         "current_quantity": 2,
#                         "fulfillable_quantity": 0,
#                         "fulfillment_service": "manual",
#                         "fulfillment_status": "fulfilled",
#                         "gift_card": false,
#                         "grams": 0,
#                         "name": "Mini Willow Dodger - Rainbow",
#                         "pre_tax_price": "10.00",
#                         "pre_tax_price_set": {
#                             "shop_money": {
#                                 "amount": "10.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "10.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "price": "5.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "5.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "5.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "product_exists": true,
#                         "product_id": 8779849957602,
#                         "properties": [],
#                         "quantity": 2,
#                         "requires_shipping": true,
#                         "sku": "Mini Willow Rainbow",
#                         "taxable": true,
#                         "title": "Mini Willow Dodger",
#                         "total_discount": "0.00",
#                         "total_discount_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "variant_id": 46217431154914,
#                         "variant_inventory_management": "shopify",
#                         "variant_title": "Rainbow",
#                         "vendor": "Catch America",
#                         "tax_lines": [
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.60",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.60",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.60",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.06,
#                                 "title": "California State Tax"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.03",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.03",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.03",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.0025,
#                                 "title": "Fresno County Tax"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.06",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.06",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.06",
#                                         "currency_code": "USD"
#                                     }
#                                 },
#                                 "rate": 0.00625,
#                                 "title": "Mendocino County District Tax Sp"
#                             },
#                             {
#                                 "channel_liable": false,
#                                 "price": "0.10",
#                                 "price_set": {
#                                     "shop_money": {
#                                         "amount": "0.10",
#                                         "currency_code": "USD"
#                                     },
#                                     "presentment_money": {
#                                         "amount": "0.10",
#                                         "currency_code": "USD"
# ...
#                         "currency_code": "USD"
#                     }
#                 },
#                 "price": "9.00",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "product_exists": true,
#                 "product_id": 8795040350434,
#                 "properties": [],
#                 "quantity": 1,
#                 "requires_shipping": true,
#                 "sku": "",
#                 "taxable": true,
#                 "title": "Trigger Scent by Cal Kellogg",
#                 "total_discount": "0.00",
#                 "total_discount_set": {
#                     "shop_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "variant_id": 46265682198754,
#                 "variant_inventory_management": "shopify",
#                 "variant_title": null,
#                 "vendor": "Catch America",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.02",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.02",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.02",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.09",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.09",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.09",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.54",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.54",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.54",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "duties": [],
#                 "discount_allocations": []
#             },
#             {
#                 "id": 14576518824162,
#                 "admin_graphql_api_id": "gid://shopify/LineItem/14576518824162",
#                 "attributed_staffs": [],
#                 "current_quantity": 1,
#                 "fulfillable_quantity": 0,
#                 "fulfillment_service": "manual",
#                 "fulfillment_status": "fulfilled",
#                 "gift_card": false,
#                 "grams": 0,
#                 "name": "Chrome Killer Scent by Big Nate",
#                 "pre_tax_price": "9.00",
#                 "pre_tax_price_set": {
#                     "shop_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "price": "9.00",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "9.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "product_exists": true,
#                 "product_id": 8795041071330,
#                 "properties": [],
#                 "quantity": 1,
#                 "requires_shipping": true,
#                 "sku": "",
#                 "taxable": true,
#                 "title": "Chrome Killer Scent by Big Nate",
#                 "total_discount": "0.00",
#                 "total_discount_set": {
#                     "shop_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "variant_id": 46265686393058,
#                 "variant_inventory_management": "shopify",
#                 "variant_title": null,
#                 "vendor": "Catch America",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.02",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.02",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.02",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.09",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.09",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.09",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.54",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.54",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.54",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "duties": [],
#                 "discount_allocations": []
#             },
#             {
#                 "id": 14576518856930,
#                 "admin_graphql_api_id": "gid://shopify/LineItem/14576518856930",
#                 "attributed_staffs": [],
#                 "current_quantity": 1,
#                 "fulfillable_quantity": 0,
#                 "fulfillment_service": "manual",
#                 "fulfillment_status": "fulfilled",
#                 "gift_card": false,
#                 "grams": 1361,
#                 "name": "Trolling Rudder & Weight Hanger Set",
#                 "pre_tax_price": "12.00",
#                 "pre_tax_price_set": {
#                     "shop_money": {
#                         "amount": "12.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "12.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "price": "12.00",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "12.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "12.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "product_exists": true,
#                 "product_id": 8779852611810,
#                 "properties": [],
#                 "quantity": 1,
#                 "requires_shipping": true,
#                 "sku": "Rudder Set",
#                 "taxable": true,
#                 "title": "Trolling Rudder & Weight Hanger Set",
#                 "total_discount": "0.00",
#                 "total_discount_set": {
#                     "shop_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "0.00",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "variant_id": 46217437413602,
#                 "variant_inventory_management": "shopify",
#                 "variant_title": null,
#                 "vendor": "Catch America",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.03",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.03",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.03",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.12",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.12",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.12",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.72",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.72",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.72",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "duties": [],
#                 "discount_allocations": []
#             }
#         ],
#         "payment_terms": null,
#         "refunds": [],
#         "shipping_address": {
#             "first_name": "Lonnie",
#             "address1": "13639 Garner Ln",
#             "phone": "+15306242455",
#             "city": "Chico",
#             "zip": "95973",
#             "province": "California",
#             "country": "United States",
#             "last_name": "Curtis",
#             "address2": null,
#             "company": null,
#             "latitude": 39.7982477,
#             "longitude": -121.8914223,
#             "name": "Lonnie Curtis",
#             "country_code": "US",
#             "province_code": "CA"
#         },
#         "shipping_lines": [
#             {
#                 "id": 4872917450978,
#                 "carrier_identifier": null,
#                 "code": "GroundAdvantage",
#                 "discounted_price": "6.15",
#                 "discounted_price_set": {
#                     "shop_money": {
#                         "amount": "6.15",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "6.15",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "is_removed": false,
#                 "phone": null,
#                 "price": "6.15",
#                 "price_set": {
#                     "shop_money": {
#                         "amount": "6.15",
#                         "currency_code": "USD"
#                     },
#                     "presentment_money": {
#                         "amount": "6.15",
#                         "currency_code": "USD"
#                     }
#                 },
#                 "requested_fulfillment_service_id": null,
#                 "source": "usps",
#                 "title": "Ground Advantage",
#                 "tax_lines": [
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.0025,
#                         "title": "Fresno County Tax"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.01,
#                         "title": "Fresno Co Local Tax Sl"
#                     },
#                     {
#                         "channel_liable": false,
#                         "price": "0.00",
#                         "price_set": {
#                             "shop_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             },
#                             "presentment_money": {
#                                 "amount": "0.00",
#                                 "currency_code": "USD"
#                             }
#                         },
#                         "rate": 0.06,
#                         "title": "California State Tax"
#                     }
#                 ],
#                 "discount_allocations": []
#             }
#         ]
#     }
# ]

# %%
import json
import requests
import pandas as pd

# Load Shopify credentials
with open("config.json", "r") as f:
    config = json.load(f)

SHOPIFY_STORE = config["shopify_store"]
API_KEY = config["api_key"]
PASSWORD = config["password"]

# Use the latest API version dynamically
SHOPIFY_API_VERSION = "2024-01"  # Update as needed
SHOPIFY_API_URL = f"https://{SHOPIFY_STORE}.myshopify.com/admin/api/{SHOPIFY_API_VERSION}/orders.json"

def fetch_shopify_orders():
    """Fetch sample orders from Shopify API and return a pandas DataFrame."""
    response = requests.get(SHOPIFY_API_URL, params={"status": "any", "limit": 250}, auth=(API_KEY, PASSWORD)) # increased limit for better dataframe

    if response.status_code != 200:
        print(f"Error: {response.status_code}, {response.text}")
        return pd.DataFrame() # Return an empty DataFrame on error

    orders_json = response.json().get("orders", [])

    if not orders_json:
        print("No orders found.")
        return pd.DataFrame() # Return an empty DataFrame if no orders

    # Normalize the JSON data into a DataFrame
    df = pd.json_normalize(orders_json)

    return df

orders_df = fetch_shopify_orders()

if not orders_df.empty:
    print(orders_df.head()) # Print the first few rows of the DataFrame
    print(orders_df.info()) # Print information about the DataFrame
    # Now you can perform pandas operations on orders_df
    # Example: orders_df['total_price'] = pd.to_numeric(orders_df['total_price'])
    # Example: print(orders_df['total_price'].sum())
else:
    print("Failed to retrieve or process order data.")
# Out:
#               id               admin_graphql_api_id  app_id  \
# 0  6002412257506  gid://shopify/Order/6002412257506  580111
# 1  6002019369186  gid://shopify/Order/6002019369186  580111
# 2  6001818763490  gid://shopify/Order/6001818763490  580111
# 3  6001784914146  gid://shopify/Order/6001784914146  580111
# 4  6001626972386  gid://shopify/Order/6001626972386  580111
#
#                                browser_ip  buyer_accepts_marketing  \
# 0                          172.56.179.126                     True
# 1  2601:648:4200:95b0:750c:14a6:7df5:7238                     True
# 2                            12.75.243.83                     True
# 3                            68.67.95.188                     True
# 4  2601:206:8381:5850:f98b:26a0:6ff0:bc9f                     True
#
#   cancel_reason cancelled_at  \
# 0          None         None
# 1          None         None
# 2          None         None
# 3          None         None
# 4          None         None
#
#                                           cart_token     checkout_id  \
# 0  Z2NwLXVzLXdlc3QxOjAxSk1KNTgxR1lCM1dRNEo4QVFGRV...  35677846601954
# 1  Z2NwLXVzLXdlc3QxOjAxSk1IQlBUWjNISEQ4VjRSUkc2Q1...  35676923560162
# 2  Z2NwLXVzLWNlbnRyYWwxOjAxSk1HUjU1UDlHQjZSN1o2RT...  35676315255010
# 3  Z2NwLXVzLXdlc3QxOjAxSk1HTk1YTUhRSjRCQVczMDdSSj...  35676219834594
# 4  Z2NwLXVzLXdlc3QxOjAxSk1HOERDTVFWS0U4WjFCMkUySj...  35675710128354
#
#                      checkout_token  ... shipping_address.latitude  \
# 0  b196101e74ae5c56567a12094ff992f6  ...                 34.000778
# 1  c89a4f145d612bfa9410a80dda64e811  ...                 39.270662
# 2  7b42fe5b0111d9ff9b05546b1e7beb1c  ...                       NaN
# 3  4e17a999a20a412a13bb228ae458d606  ...                 38.794447
# 4  050fdf0bf8de99d5d07751469df6da91  ...                 39.798248
#
#   shipping_address.longitude  shipping_address.name  \
# 0                -117.735585       Adrian Gutierrez
# 1                -123.196028           Ryan Demarta
# 2                        NaN            Michael Pai
# 3                -121.259350              Mike Mike
# 4                -121.891422          Lonnie Curtis
#
#   shipping_address.country_code shipping_address.province_code  \
# 0                            US                             CA
# 1                            US                             CA
# 2                            US                             CA
# 3                            US                             CA
# 4                            US                             CA
#
#   customer.sms_marketing_consent.state  \
# 0                                  NaN
# 1                                  NaN
# 2                           subscribed
# 3                                  NaN
# 4                                  NaN
#
#   customer.sms_marketing_consent.opt_in_level  \
# 0                                         NaN
# 1                                         NaN
# 2                               single_opt_in
# 3                                         NaN
# 4                                         NaN
#
#   customer.sms_marketing_consent.consent_updated_at  \
# 0                                               NaN
# 1                                               NaN
# 2                         2025-01-30T18:17:17-08:00
# 3                                               NaN
# 4                                               NaN
#
#   customer.sms_marketing_consent.consent_collected_from  \
# 0                                                NaN
# 1                                                NaN
# 2                                            SHOPIFY
# 3                                                NaN
# 4                                                NaN
#
#   customer.email_marketing_consent
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 191 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Columns: 191 entries, id to customer.email_marketing_consent
# dtypes: bool(9), float64(7), int64(9), object(166)
# memory usage: 357.8+ KB
# None

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Columns: 191 entries, id to customer.email_marketing_consent
# dtypes: bool(9), float64(7), int64(9), object(166)
# memory usage: 357.8+ KB

# %%
df_columns = orders_df.columns.to_list()
df_columns
# Out:
# ['id',
#  'admin_graphql_api_id',
#  'app_id',
#  'browser_ip',
#  'buyer_accepts_marketing',
#  'cancel_reason',
#  'cancelled_at',
#  'cart_token',
#  'checkout_id',
#  'checkout_token',
#  'closed_at',
#  'confirmation_number',
#  'confirmed',
#  'contact_email',
#  'created_at',
#  'currency',
#  'current_subtotal_price',
#  'current_total_additional_fees_set',
#  'current_total_discounts',
#  'current_total_duties_set',
#  'current_total_price',
#  'current_total_tax',
#  'customer_locale',
#  'device_id',
#  'discount_codes',
#  'email',
#  'estimated_taxes',
#  'financial_status',
#  'fulfillment_status',
#  'landing_site',
#  'landing_site_ref',
#  'location_id',
#  'merchant_of_record_app_id',
#  'name',
#  'note',
#  'note_attributes',
#  'number',
#  'order_number',
#  'order_status_url',
#  'original_total_additional_fees_set',
#  'original_total_duties_set',
#  'payment_gateway_names',
#  'phone',
#  'po_number',
#  'presentment_currency',
#  'processed_at',
#  'reference',
#  'referring_site',
#  'source_identifier',
#  'source_name',
#  'source_url',
#  'subtotal_price',
#  'tags',
#  'tax_exempt',
#  'tax_lines',
#  'taxes_included',
#  'test',
#  'token',
#  'total_discounts',
#  'total_line_items_price',
#  'total_outstanding',
#  'total_price',
#  'total_tax',
#  'total_tip_received',
#  'total_weight',
#  'updated_at',
#  'user_id',
#  'discount_applications',
#  'fulfillments',
#  'line_items',
#  'payment_terms',
#  'refunds',
#  'shipping_lines',
#  'client_details.accept_language',
#  'client_details.browser_height',
#  'client_details.browser_ip',
#  'client_details.browser_width',
#  'client_details.session_hash',
#  'client_details.user_agent',
#  'current_subtotal_price_set.shop_money.amount',
#  'current_subtotal_price_set.shop_money.currency_code',
#  'current_subtotal_price_set.presentment_money.amount',
#  'current_subtotal_price_set.presentment_money.currency_code',
#  'current_total_discounts_set.shop_money.amount',
#  'current_total_discounts_set.shop_money.currency_code',
#  'current_total_discounts_set.presentment_money.amount',
#  'current_total_discounts_set.presentment_money.currency_code',
#  'current_total_price_set.shop_money.amount',
#  'current_total_price_set.shop_money.currency_code',
#  'current_total_price_set.presentment_money.amount',
#  'current_total_price_set.presentment_money.currency_code',
#  'current_total_tax_set.shop_money.amount',
#  'current_total_tax_set.shop_money.currency_code',
#  'current_total_tax_set.presentment_money.amount',
#  'current_total_tax_set.presentment_money.currency_code',
#  'subtotal_price_set.shop_money.amount',
#  'subtotal_price_set.shop_money.currency_code',
#  'subtotal_price_set.presentment_money.amount',
#  'subtotal_price_set.presentment_money.currency_code',
#  'total_discounts_set.shop_money.amount',
#  'total_discounts_set.shop_money.currency_code',
#  'total_discounts_set.presentment_money.amount',
#  'total_discounts_set.presentment_money.currency_code',
#  'total_line_items_price_set.shop_money.amount',
#  'total_line_items_price_set.shop_money.currency_code',
#  'total_line_items_price_set.presentment_money.amount',
#  'total_line_items_price_set.presentment_money.currency_code',
#  'total_price_set.shop_money.amount',
#  'total_price_set.shop_money.currency_code',
#  'total_price_set.presentment_money.amount',
#  'total_price_set.presentment_money.currency_code',
#  'total_shipping_price_set.shop_money.amount',
#  'total_shipping_price_set.shop_money.currency_code',
#  'total_shipping_price_set.presentment_money.amount',
#  'total_shipping_price_set.presentment_money.currency_code',
#  'total_tax_set.shop_money.amount',
#  'total_tax_set.shop_money.currency_code',
#  'total_tax_set.presentment_money.amount',
#  'total_tax_set.presentment_money.currency_code',
#  'billing_address.first_name',
#  'billing_address.address1',
#  'billing_address.phone',
#  'billing_address.city',
#  'billing_address.zip',
#  'billing_address.province',
#  'billing_address.country',
#  'billing_address.last_name',
#  'billing_address.address2',
#  'billing_address.company',
#  'billing_address.latitude',
#  'billing_address.longitude',
#  'billing_address.name',
#  'billing_address.country_code',
#  'billing_address.province_code',
#  'customer.id',
#  'customer.email',
#  'customer.created_at',
#  'customer.updated_at',
#  'customer.first_name',
#  'customer.last_name',
#  'customer.state',
#  'customer.note',
#  'customer.verified_email',
#  'customer.multipass_identifier',
#  'customer.tax_exempt',
#  'customer.phone',
#  'customer.email_marketing_consent.state',
#  'customer.email_marketing_consent.opt_in_level',
#  'customer.email_marketing_consent.consent_updated_at',
#  'customer.sms_marketing_consent',
#  'customer.tags',
#  'customer.currency',
#  'customer.tax_exemptions',
#  'customer.admin_graphql_api_id',
#  'customer.default_address.id',
#  'customer.default_address.customer_id',
#  'customer.default_address.first_name',
#  'customer.default_address.last_name',
#  'customer.default_address.company',
#  'customer.default_address.address1',
#  'customer.default_address.address2',
#  'customer.default_address.city',
#  'customer.default_address.province',
#  'customer.default_address.country',
#  'customer.default_address.zip',
#  'customer.default_address.phone',
#  'customer.default_address.name',
#  'customer.default_address.province_code',
#  'customer.default_address.country_code',
#  'customer.default_address.country_name',
#  'customer.default_address.default',
#  'shipping_address.first_name',
#  'shipping_address.address1',
#  'shipping_address.phone',
#  'shipping_address.city',
#  'shipping_address.zip',
#  'shipping_address.province',
#  'shipping_address.country',
#  'shipping_address.last_name',
#  'shipping_address.address2',
#  'shipping_address.company',
#  'shipping_address.latitude',
#  'shipping_address.longitude',
#  'shipping_address.name',
#  'shipping_address.country_code',
#  'shipping_address.province_code',
#  'customer.sms_marketing_consent.state',
#  'customer.sms_marketing_consent.opt_in_level',
#  'customer.sms_marketing_consent.consent_updated_at',
#  'customer.sms_marketing_consent.consent_collected_from',
#  'customer.email_marketing_consent']

# %%
# Script version 2: fetched 12322 recrods since 2024-12-28
'''

import json
import requests
import google.auth
import time
from datetime import datetime, timezone
from google.cloud import bigquery

# Load Shopify credentials
with open("config.json", "r") as f:
    config = json.load(f)

SHOPIFY_STORE = config["shopify_store"]
API_KEY = config["api_key"]
PASSWORD = config["password"]
SHOPIFY_API_VERSION = "2024-01"
SHOPIFY_API_URL = f"https://{SHOPIFY_STORE}.myshopify.com/admin/api/{SHOPIFY_API_VERSION}/orders.json"

# BigQuery Setup
client = bigquery.Client()
DATASET_ID = "Shopify"
TABLE_ID = "shopify_orders"
CONTROL_TABLE = "pipeline_metadata.sync_control"

class ShopifyETLPipeline:
    def __init__(self):
        self.control_table = CONTROL_TABLE

    def get_last_sync_timestamp(self):
        """Retrieve the last successful sync timestamp from BigQuery."""
        query = f"""
        SELECT last_sync_timestamp 
        FROM `{self.control_table}`
        WHERE table_name = 'shopify_orders'
        ORDER BY last_sync_timestamp DESC
        LIMIT 1
        """
        query_job = client.query(query)
        results = list(query_job.result())
        return results[0]["last_sync_timestamp"] if results else None

    def update_sync_timestamp(self, records_processed):
        """Update the last sync timestamp in BigQuery."""
        query = f"""
        MERGE INTO `{self.control_table}` T
        USING (SELECT 'shopify_orders' AS table_name, CURRENT_TIMESTAMP() AS last_sync_timestamp, {records_processed} AS records_processed) S
        ON T.table_name = S.table_name
        WHEN MATCHED THEN UPDATE SET T.last_sync_timestamp = S.last_sync_timestamp, T.records_processed = S.records_processed
        WHEN NOT MATCHED THEN INSERT (table_name, last_sync_timestamp, records_processed) VALUES (S.table_name, S.last_sync_timestamp, S.records_processed)
        """
        client.query(query).result()
        print(f"Updated last sync timestamp: {datetime.now(timezone.utc)}")

    def fetch_shopify_data(self, start_date=None):
        """Fetch all Shopify orders, handling pagination."""
        params = {
            "status": "any",
            "limit": 250,
            "order": "asc"
        }
        if start_date:
            params["updated_at_min"] = start_date

        all_orders = []
        page_count = 1
        next_page_info = None

        while True:
            print(f"Fetching page {page_count}...")

            if next_page_info:
                # If paginating, remove conflicting params and use page_info
                params = {"limit": 250, "page_info": next_page_info}

            response = requests.get(SHOPIFY_API_URL, params=params, auth=(API_KEY, PASSWORD))

            if response.status_code == 429:
                retry_after = int(response.headers.get("Retry-After", 60))
                print(f"Rate limit hit. Retrying in {retry_after} seconds...")
                time.sleep(retry_after)
                continue

            if response.status_code != 200:
                print(f"API Error: {response.status_code}, {response.text}")
                break

            orders = response.json().get("orders", [])
            if not orders:
                print("No more orders found, exiting pagination.")
                break  # No more records, exit loop

            for order in orders:
                all_orders.append({
                    "order_id": str(order["id"]),
                    "created_at": order["created_at"],
                    "updated_at": order["updated_at"],
                    "processed_at": order.get("processed_at"),
                    "total_price": float(order["total_price"]),
                    "subtotal_price": float(order["subtotal_price"]),
                    "total_tax": float(order["total_tax"]),
                    "total_discounts": float(order["total_discounts"]),
                    "currency": order["currency"],
                    "financial_status": order.get("financial_status", ""),
                    "fulfillment_status": order.get("fulfillment_status", ""),
                    "customer_locale": order.get("customer_locale", ""),
                    "customer_email": order.get("contact_email", ""),
                    "customer_id": str(order["customer"]["id"]) if order.get("customer") else None,
                    "buyer_accepts_marketing": order.get("buyer_accepts_marketing", False),
                    "discount_codes": json.dumps(order.get("discount_codes", [])),
                    "payment_gateway_names": json.dumps(order.get("payment_gateway_names", [])),
                    "source_name": order.get("source_name"),
                    "referring_site": order.get("referring_site")
                })

            print(f"Fetched {len(orders)} orders on page {page_count}. Total collected: {len(all_orders)}")

            # Extract `page_info` from Shopify API response for pagination
            link_header = response.headers.get("Link")
            if link_header and "rel=\"next\"" in link_header:
                next_page_info = link_header.split("page_info=")[-1].split(">")[0]
                page_count += 1
            else:
                print("Pagination complete.")
                break  # No more pages, exit loop

        return all_orders

    def load_to_bigquery(self, orders):
        """Upsert orders into BigQuery."""
        table_ref = client.dataset(DATASET_ID).table(TABLE_ID)
        errors = client.insert_rows_json(table_ref, orders)

        if errors:
            print(f"BigQuery insertion errors: {errors}")
        else:
            print(f"Successfully inserted {len(orders)} rows into {TABLE_ID}")

    def execute(self, force_full_load=False):
        """Main execution function to handle historical & incremental loads."""
        last_sync = self.get_last_sync_timestamp() if not force_full_load else None

        if last_sync is None:
            print("Performing full historical load from 2024-01-01")
            orders = self.fetch_shopify_data(start_date="2024-01-01")
        else:
            print(f"Performing incremental load since {last_sync}")
            orders = self.fetch_shopify_data(start_date=last_sync)

        if orders:
            self.load_to_bigquery(orders)
            self.update_sync_timestamp(len(orders))
        else:
            print("No new orders to load.")

# Usage:
pipeline = ShopifyETLPipeline()

# For historical load (only run once):
pipeline.execute(force_full_load=True)

# For regular incremental runs (new data only):
pipeline.execute()
'''

# %%
orders_df.describe()
# Out:
#                  id        app_id   checkout_id        number  order_number  \
# count  2.500000e+02  2.500000e+02  2.500000e+02    250.000000    250.000000
# mean   5.987192e+12  6.251881e+05  3.563668e+13  12203.500000  13203.500000
# std    9.235861e+09  3.169529e+05  2.528734e+10     72.312977     72.312977
# min    5.972349e+12  5.801110e+05  3.557361e+13  12079.000000  13079.000000
# 25%    5.978110e+12  5.801110e+05  3.561339e+13  12141.250000  13141.250000
# 50%    5.987117e+12  5.801110e+05  3.563557e+13  12203.500000  13203.500000
# 75%    5.995434e+12  5.801110e+05  3.565833e+13  12265.750000  13265.750000
# max    6.002412e+12  3.890849e+06  3.567785e+13  12328.000000  13328.000000
#
#        total_weight       user_id  billing_address.latitude  \
# count    250.000000  6.000000e+00                 91.000000
# mean     521.280000  9.460599e+10                 38.403551
# std     2068.184005  1.738805e+08                  2.295584
# min        0.000000  9.425106e+10                 30.548465
# 25%        0.000000  9.467698e+10                 37.744138
# 50%        0.000000  9.467698e+10                 38.359190
# 75%        0.000000  9.467698e+10                 38.748221
# max    21047.000000  9.467698e+10                 47.561335
#
#        billing_address.longitude   customer.id  \
# count                  91.000000  2.500000e+02
# mean                 -117.650261  7.839510e+12
# std                    11.595448  4.671871e+10
# min                  -123.355566  7.794139e+12
# 25%                  -122.103994  7.794656e+12
# 50%                  -121.376799  7.844440e+12
# 75%                  -120.988160  7.867402e+12
# max                   -71.849987  7.925031e+12
#
#        customer.sms_marketing_consent  customer.default_address.id  \
# count                             0.0                 2.500000e+02
# mean                              NaN                 9.413559e+12
# std                               NaN                 2.321218e+10
# min                               NaN                 9.349154e+12
# 25%                               NaN                 9.409519e+12
# 50%                               NaN                 9.417958e+12
# 75%                               NaN                 9.428522e+12
# max                               NaN                 9.436685e+12
#
#        customer.default_address.customer_id  shipping_address.latitude  \
# count                          2.500000e+02                 228.000000
# mean                           7.839510e+12                  38.501571
# std                            4.671871e+10                   2.638087
# min                            7.794139e+12                  30.589738
# 25%                            7.794656e+12                  37.783883
# 50%                            7.844440e+12                  38.444121
# 75%                            7.867402e+12                  38.910004
# max                            7.925031e+12                  49.121667
#
#        shipping_address.longitude  customer.email_marketing_consent
# count                  228.000000                               0.0
# mean                  -118.393124                               NaN
# std                     10.004304                               NaN
# min                   -124.246177                               NaN
# 25%                   -122.017420                               NaN
# 50%                   -121.321099                               NaN
# 75%                   -120.522773                               NaN
# max                    -69.774546                               NaN

# %%
orders_df['line_items']
# Out:
# 0      [{'id': 14577930404066, 'admin_graphql_api_id'...
# 1      [{'id': 14577224876258, 'admin_graphql_api_id'...
# 2      [{'id': 14576878026978, 'admin_graphql_api_id'...
# 3      [{'id': 14576813310178, 'admin_graphql_api_id'...
# 4      [{'id': 14576518758626, 'admin_graphql_api_id'...
#                              ...
# 245    [{'id': 14523626881250, 'admin_graphql_api_id'...
# 246    [{'id': 14523417264354, 'admin_graphql_api_id'...
# 247    [{'id': 14523388428514, 'admin_graphql_api_id'...
# 248    [{'id': 14523160264930, 'admin_graphql_api_id'...
# 249    [{'id': 14522158383330, 'admin_graphql_api_id'...
# Name: line_items, Length: 250, dtype: object

# %%
orders_df['line_items'].to_list()
# Out:
# [[{'id': 14577930404066,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577930404066',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 2,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': None,
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trix Rigging Kit',
#    'pre_tax_price': '11.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.00', 'currency_code': 'USD'}},
#    'price': '5.50',
#    'price_set': {'shop_money': {'amount': '5.50', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788626440418,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trix Rigging Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249009512674,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'San Bernardino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.11',
#      'price_set': {'shop_money': {'amount': '0.11', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.11', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.66',
#      'price_set': {'shop_money': {'amount': '0.66', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.66', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577930436834,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577930436834',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 2,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': None,
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trout Trix Worms Kit',
#    'pre_tax_price': '30.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '30.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '30.00', 'currency_code': 'USD'}},
#    'price': '15.00',
#    'price_set': {'shop_money': {'amount': '15.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788658585826,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trout Trix Worms Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249130328290,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.08',
#      'price_set': {'shop_money': {'amount': '0.08', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.08', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'San Bernardino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.30',
#      'price_set': {'shop_money': {'amount': '0.30', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.30', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '1.80',
#      'price_set': {'shop_money': {'amount': '1.80', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '1.80', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14577224876258,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577224876258',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Scent by Cal Kellogg',
#    'pre_tax_price': '9.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '9.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#    'price': '9.00',
#    'price_set': {'shop_money': {'amount': '9.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8795040350434,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trigger Scent by Cal Kellogg',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46265682198754,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.54',
#      'price_set': {'shop_money': {'amount': '0.54', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.54', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.02',
#      'price_set': {'shop_money': {'amount': '0.02', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.02', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.09',
#      'price_set': {'shop_money': {'amount': '0.09', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.09', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577224909026,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577224909026',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Mini Willow Dodger - Rainbow',
#    'pre_tax_price': '10.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '10.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '10.00', 'currency_code': 'USD'}},
#    'price': '5.00',
#    'price_set': {'shop_money': {'amount': '5.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779849957602,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': 'Mini Willow Rainbow',
#    'taxable': True,
#    'title': 'Mini Willow Dodger',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217431154914,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Rainbow',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.60',
#      'price_set': {'shop_money': {'amount': '0.60', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.60', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.10',
#      'price_set': {'shop_money': {'amount': '0.10', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.10', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577224941794,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577224941794',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 1361,
#    'name': 'Trolling Rudder & Weight Hanger Set',
#    'pre_tax_price': '24.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '24.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '24.00', 'currency_code': 'USD'}},
#    'price': '12.00',
#    'price_set': {'shop_money': {'amount': '12.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779852611810,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': 'Rudder Set',
#    'taxable': True,
#    'title': 'Trolling Rudder & Weight Hanger Set',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217437413602,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '1.44',
#      'price_set': {'shop_money': {'amount': '1.44', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '1.44', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.24',
#      'price_set': {'shop_money': {'amount': '0.24', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.24', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577224974562,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577224974562',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Turbo Flasher - Pink',
#    'pre_tax_price': '12.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '12.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#    'price': '12.00',
#    'price_set': {'shop_money': {'amount': '12.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779861459170,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'TF -Pink',
#    'taxable': True,
#    'title': 'Turbo Flasher',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217476899042,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Pink',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.08',
#      'price_set': {'shop_money': {'amount': '0.08', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.08', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225007330,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225007330',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Pink Poison',
#    'pre_tax_price': '5.99',
#    'pre_tax_price_set': {'shop_money': {'amount': '5.99',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46360430084322,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Pink Poison',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.36',
#      'price_set': {'shop_money': {'amount': '0.36', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.36', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225040098,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225040098',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trix Rigging Kit',
#    'pre_tax_price': '5.50',
#    'pre_tax_price_set': {'shop_money': {'amount': '5.50',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#    'price': '5.50',
#    'price_set': {'shop_money': {'amount': '5.50', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788626440418,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trix Rigging Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249009512674,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.33',
#      'price_set': {'shop_money': {'amount': '0.33', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.33', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225072866,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225072866',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Bulk Trout Trix Grubs - Bulk Firecracker',
#    'pre_tax_price': '10.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '10.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '10.00', 'currency_code': 'USD'}},
#    'price': '10.00',
#    'price_set': {'shop_money': {'amount': '10.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '10.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779850023138,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'Bulk Grub Firecracker',
#    'taxable': True,
#    'title': 'Bulk Trout Trix Grubs',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217431548130,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Bulk Firecracker',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.60',
#      'price_set': {'shop_money': {'amount': '0.60', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.60', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.10',
#      'price_set': {'shop_money': {'amount': '0.10', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.10', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225105634,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225105634',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trout Trix Worms Kit',
#    'pre_tax_price': '15.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '15.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'price': '15.00',
#    'price_set': {'shop_money': {'amount': '15.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788658585826,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trout Trix Worms Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249130328290,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.90',
#      'price_set': {'shop_money': {'amount': '0.90', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.90', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.09',
#      'price_set': {'shop_money': {'amount': '0.09', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.09', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225138402,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225138402',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Metal Head Fly - Captain America',
#    'pre_tax_price': '3.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '3.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'price': '3.95',
#    'price_set': {'shop_money': {'amount': '3.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779859591394,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'MH CapAm',
#    'taxable': True,
#    'title': 'Metal Head Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217468248290,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Captain America',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.24',
#      'price_set': {'shop_money': {'amount': '0.24', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.24', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.02',
#      'price_set': {'shop_money': {'amount': '0.02', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.02', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14577225171170,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14577225171170',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Collins Lake Kit by Cal Kellogg',
#    'pre_tax_price': '19.89',
#    'pre_tax_price_set': {'shop_money': {'amount': '19.89',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '19.89', 'currency_code': 'USD'}},
#    'price': '19.89',
#    'price_set': {'shop_money': {'amount': '19.89', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '19.89', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8798538268898,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Collins Lake Kit by Cal Kellogg',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46274921038050,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '1.19',
#      'price_set': {'shop_money': {'amount': '1.19', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '1.19', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.05',
#      'price_set': {'shop_money': {'amount': '0.05', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.05', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.00625,
#      'title': 'Mendocino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.20',
#      'price_set': {'shop_money': {'amount': '0.20', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.20', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14576878026978,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576878026978',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Blue Shad',
#    'pre_tax_price': '11.98',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.98',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.98', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46360434606306,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Blue Shad',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'Sacramento County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576878059746,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576878059746',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Clown Shad',
#    'pre_tax_price': '11.98',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.98',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.98', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': 'TS CLown Shad-1',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217504522466,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Clown Shad',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'Sacramento County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576878092514,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576878092514',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Sunrise Firetiger',
#    'pre_tax_price': '11.98',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.98',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.98', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46278236438754,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Sunrise Firetiger',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'Sacramento County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576878125282,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576878125282',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Orange Shad',
#    'pre_tax_price': '11.98',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.98',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.98', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': 'TS Orange Shad-1',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217504915682,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Orange Shad',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'Sacramento County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576878158050,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576878158050',
#    'attributed_staffs': [],
#    'current_quantity': 2,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Spoon - Sexy Shad',
#    'pre_tax_price': '11.98',
#    'pre_tax_price_set': {'shop_money': {'amount': '11.98',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '11.98', 'currency_code': 'USD'}},
#    'price': '5.99',
#    'price_set': {'shop_money': {'amount': '5.99', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.99', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779865161954,
#    'properties': [],
#    'quantity': 2,
#    'requires_shipping': True,
#    'sku': 'TS Sexy Shad-1',
#    'taxable': True,
#    'title': 'Trigger Spoon',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217504817378,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Sexy Shad',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'Sacramento County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14576813310178,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576813310178',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Turbo Flasher - Wonder Bread',
#    'pre_tax_price': '12.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '12.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#    'price': '12.00',
#    'price_set': {'shop_money': {'amount': '12.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779861459170,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'TF -Wonder Bread',
#    'taxable': True,
#    'title': 'Turbo Flasher',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217476964578,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Wonder Bread',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.12',
#      'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.72',
#      'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576813342946,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576813342946',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trout Trix Minnow Kit',
#    'pre_tax_price': '15.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '15.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'price': '15.00',
#    'price_set': {'shop_money': {'amount': '15.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788522270946,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trout Trix Minnow Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46248783904994,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.90',
#      'price_set': {'shop_money': {'amount': '0.90', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.90', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576813375714,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576813375714',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Metal Head Fly - Pink and White',
#    'pre_tax_price': '3.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '3.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'price': '3.95',
#    'price_set': {'shop_money': {'amount': '3.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779859591394,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'Metal Head- Pink/ White',
#    'taxable': True,
#    'title': 'Metal Head Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217468870882,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Pink and White',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.24',
#      'price_set': {'shop_money': {'amount': '0.24', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.24', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14576813408482,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576813408482',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Metal Head Fly - Orange',
#    'pre_tax_price': '3.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '3.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'price': '3.95',
#    'price_set': {'shop_money': {'amount': '3.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '3.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779859591394,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'Metal Head- Orange',
#    'taxable': True,
#    'title': 'Metal Head Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217468903650,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Orange',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.24',
#      'price_set': {'shop_money': {'amount': '0.24', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.24', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14576518758626,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14576518758626',
#    'attributed_staffs': [],
# ...
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Yuba County District Tax Sp'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14523418738914,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523418738914',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Bugger Trolling Fly - Black',
#    'pre_tax_price': '2.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '2.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'price': '2.95',
#    'price_set': {'shop_money': {'amount': '2.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779864277218,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'WB Fly- Blk',
#    'taxable': True,
#    'title': 'Trigger Bugger Trolling Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217493217506,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Black',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.18',
#      'price_set': {'shop_money': {'amount': '0.18', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.18', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Yuba County District Tax Sp'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14523418771682,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523418771682',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Bugger Trolling Fly - Pink',
#    'pre_tax_price': '2.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '2.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'price': '2.95',
#    'price_set': {'shop_money': {'amount': '2.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779864277218,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'WB Fly- Pink',
#    'taxable': True,
#    'title': 'Trigger Bugger Trolling Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217493250274,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Pink',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.18',
#      'price_set': {'shop_money': {'amount': '0.18', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.18', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Yuba County District Tax Sp'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14523418804450,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523418804450',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trigger Bugger Trolling Fly - Confetti',
#    'pre_tax_price': '2.95',
#    'pre_tax_price_set': {'shop_money': {'amount': '2.95',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'price': '2.95',
#    'price_set': {'shop_money': {'amount': '2.95', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '2.95', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779864277218,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trigger Bugger Trolling Fly',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46278163464418,
#    'variant_inventory_management': 'shopify',
#    'variant_title': 'Confetti',
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.18',
#      'price_set': {'shop_money': {'amount': '0.18', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.18', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'},
#     {'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Yuba County District Tax Sp'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14523388428514,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523388428514',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trout Trix Worms Kit',
#    'pre_tax_price': '15.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '15.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'price': '15.00',
#    'price_set': {'shop_money': {'amount': '15.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788658585826,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trout Trix Worms Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249130328290,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.00',
#      'price_set': {'shop_money': {'amount': '0.00', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#      'rate': 0.0,
#      'title': 'Washington State Tax'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14523160264930,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523160264930',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trix Rigging Kit',
#    'pre_tax_price': '5.50',
#    'pre_tax_price_set': {'shop_money': {'amount': '5.50',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#    'price': '5.50',
#    'price_set': {'shop_money': {'amount': '5.50', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788626440418,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trix Rigging Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249009512674,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.01',
#      'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Redlands City Tax'},
#     {'channel_liable': False,
#      'price': '0.03',
#      'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'San Bernardino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.06',
#      'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.33',
#      'price_set': {'shop_money': {'amount': '0.33', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.33', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []},
#   {'id': 14523160297698,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14523160297698',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 0,
#    'name': 'Trout Trix Worms Kit',
#    'pre_tax_price': '15.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '15.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'price': '15.00',
#    'price_set': {'shop_money': {'amount': '15.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '15.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8788658585826,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': '',
#    'taxable': True,
#    'title': 'Trout Trix Worms Kit',
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46249130328290,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.04',
#      'price_set': {'shop_money': {'amount': '0.04', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.04', 'currency_code': 'USD'}},
#      'rate': 0.0025,
#      'title': 'Fresno County Tax'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Redlands City Tax'},
#     {'channel_liable': False,
#      'price': '0.08',
#      'price_set': {'shop_money': {'amount': '0.08', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.08', 'currency_code': 'USD'}},
#      'rate': 0.005,
#      'title': 'San Bernardino County District Tax Sp'},
#     {'channel_liable': False,
#      'price': '0.15',
#      'price_set': {'shop_money': {'amount': '0.15', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.15', 'currency_code': 'USD'}},
#      'rate': 0.01,
#      'title': 'Fresno Co Local Tax Sl'},
#     {'channel_liable': False,
#      'price': '0.90',
#      'price_set': {'shop_money': {'amount': '0.90', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.90', 'currency_code': 'USD'}},
#      'rate': 0.06,
#      'title': 'California State Tax'}],
#    'duties': [],
#    'discount_allocations': []}],
#  [{'id': 14522158383330,
#    'admin_graphql_api_id': 'gid://shopify/LineItem/14522158383330',
#    'attributed_staffs': [],
#    'current_quantity': 1,
#    'fulfillable_quantity': 0,
#    'fulfillment_service': 'manual',
#    'fulfillment_status': 'fulfilled',
#    'gift_card': False,
#    'grams': 454,
#    'name': "Cal's Leadcore Trolling Rod",
#    'pre_tax_price': '89.00',
#    'pre_tax_price_set': {'shop_money': {'amount': '89.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '89.00', 'currency_code': 'USD'}},
#    'price': '89.00',
#    'price_set': {'shop_money': {'amount': '89.00', 'currency_code': 'USD'},
#     'presentment_money': {'amount': '89.00', 'currency_code': 'USD'}},
#    'product_exists': True,
#    'product_id': 8779847958754,
#    'properties': [],
#    'quantity': 1,
#    'requires_shipping': True,
#    'sku': 'Leadcore Rod',
#    'taxable': True,
#    'title': "Cal's Leadcore Trolling Rod",
#    'total_discount': '0.00',
#    'total_discount_set': {'shop_money': {'amount': '0.00',
#      'currency_code': 'USD'},
#     'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#    'variant_id': 46217427124450,
#    'variant_inventory_management': 'shopify',
#    'variant_title': None,
#    'vendor': 'Catch America',
#    'tax_lines': [{'channel_liable': False,
#      'price': '0.00',
#      'price_set': {'shop_money': {'amount': '0.00', 'currency_code': 'USD'},
#       'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#      'rate': 0.0,
#      'title': 'Missouri State Tax'}],
#    'duties': [],
#    'discount_allocations': []}]]

# %%
orders_df['line_items'][0]
# Out:
# [{'id': 14576518758626,
#   'admin_graphql_api_id': 'gid://shopify/LineItem/14576518758626',
#   'attributed_staffs': [],
#   'current_quantity': 1,
#   'fulfillable_quantity': 1,
#   'fulfillment_service': 'manual',
#   'fulfillment_status': None,
#   'gift_card': False,
#   'grams': 0,
#   'name': 'Trix Rigging Kit',
#   'pre_tax_price': '5.50',
#   'pre_tax_price_set': {'shop_money': {'amount': '5.50',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#   'price': '5.50',
#   'price_set': {'shop_money': {'amount': '5.50', 'currency_code': 'USD'},
#    'presentment_money': {'amount': '5.50', 'currency_code': 'USD'}},
#   'product_exists': True,
#   'product_id': 8788626440418,
#   'properties': [],
#   'quantity': 1,
#   'requires_shipping': True,
#   'sku': '',
#   'taxable': True,
#   'title': 'Trix Rigging Kit',
#   'total_discount': '0.00',
#   'total_discount_set': {'shop_money': {'amount': '0.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#   'variant_id': 46249009512674,
#   'variant_inventory_management': 'shopify',
#   'variant_title': None,
#   'vendor': 'Catch America',
#   'tax_lines': [{'channel_liable': False,
#     'price': '0.01',
#     'price_set': {'shop_money': {'amount': '0.01', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.01', 'currency_code': 'USD'}},
#     'rate': 0.0025,
#     'title': 'Fresno County Tax'},
#    {'channel_liable': False,
#     'price': '0.06',
#     'price_set': {'shop_money': {'amount': '0.06', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.06', 'currency_code': 'USD'}},
#     'rate': 0.01,
#     'title': 'Fresno Co Local Tax Sl'},
#    {'channel_liable': False,
#     'price': '0.33',
#     'price_set': {'shop_money': {'amount': '0.33', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.33', 'currency_code': 'USD'}},
#     'rate': 0.06,
#     'title': 'California State Tax'}],
#   'duties': [],
#   'discount_allocations': []},
#  {'id': 14576518791394,
#   'admin_graphql_api_id': 'gid://shopify/LineItem/14576518791394',
#   'attributed_staffs': [],
#   'current_quantity': 1,
#   'fulfillable_quantity': 1,
#   'fulfillment_service': 'manual',
#   'fulfillment_status': None,
#   'gift_card': False,
#   'grams': 0,
#   'name': 'Trigger Scent by Cal Kellogg',
#   'pre_tax_price': '9.00',
#   'pre_tax_price_set': {'shop_money': {'amount': '9.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#   'price': '9.00',
#   'price_set': {'shop_money': {'amount': '9.00', 'currency_code': 'USD'},
#    'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#   'product_exists': True,
#   'product_id': 8795040350434,
#   'properties': [],
#   'quantity': 1,
#   'requires_shipping': True,
#   'sku': '',
#   'taxable': True,
#   'title': 'Trigger Scent by Cal Kellogg',
#   'total_discount': '0.00',
#   'total_discount_set': {'shop_money': {'amount': '0.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#   'variant_id': 46265682198754,
#   'variant_inventory_management': 'shopify',
#   'variant_title': None,
#   'vendor': 'Catch America',
#   'tax_lines': [{'channel_liable': False,
#     'price': '0.02',
#     'price_set': {'shop_money': {'amount': '0.02', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.02', 'currency_code': 'USD'}},
#     'rate': 0.0025,
#     'title': 'Fresno County Tax'},
#    {'channel_liable': False,
#     'price': '0.09',
#     'price_set': {'shop_money': {'amount': '0.09', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.09', 'currency_code': 'USD'}},
#     'rate': 0.01,
#     'title': 'Fresno Co Local Tax Sl'},
#    {'channel_liable': False,
#     'price': '0.54',
#     'price_set': {'shop_money': {'amount': '0.54', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.54', 'currency_code': 'USD'}},
#     'rate': 0.06,
#     'title': 'California State Tax'}],
#   'duties': [],
#   'discount_allocations': []},
#  {'id': 14576518824162,
#   'admin_graphql_api_id': 'gid://shopify/LineItem/14576518824162',
#   'attributed_staffs': [],
#   'current_quantity': 1,
#   'fulfillable_quantity': 1,
#   'fulfillment_service': 'manual',
#   'fulfillment_status': None,
#   'gift_card': False,
#   'grams': 0,
#   'name': 'Chrome Killer Scent by Big Nate',
#   'pre_tax_price': '9.00',
#   'pre_tax_price_set': {'shop_money': {'amount': '9.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#   'price': '9.00',
#   'price_set': {'shop_money': {'amount': '9.00', 'currency_code': 'USD'},
#    'presentment_money': {'amount': '9.00', 'currency_code': 'USD'}},
#   'product_exists': True,
#   'product_id': 8795041071330,
#   'properties': [],
#   'quantity': 1,
#   'requires_shipping': True,
#   'sku': '',
#   'taxable': True,
#   'title': 'Chrome Killer Scent by Big Nate',
#   'total_discount': '0.00',
#   'total_discount_set': {'shop_money': {'amount': '0.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#   'variant_id': 46265686393058,
#   'variant_inventory_management': 'shopify',
#   'variant_title': None,
#   'vendor': 'Catch America',
#   'tax_lines': [{'channel_liable': False,
#     'price': '0.02',
#     'price_set': {'shop_money': {'amount': '0.02', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.02', 'currency_code': 'USD'}},
#     'rate': 0.0025,
#     'title': 'Fresno County Tax'},
#    {'channel_liable': False,
#     'price': '0.09',
#     'price_set': {'shop_money': {'amount': '0.09', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.09', 'currency_code': 'USD'}},
#     'rate': 0.01,
#     'title': 'Fresno Co Local Tax Sl'},
#    {'channel_liable': False,
#     'price': '0.54',
#     'price_set': {'shop_money': {'amount': '0.54', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.54', 'currency_code': 'USD'}},
#     'rate': 0.06,
#     'title': 'California State Tax'}],
#   'duties': [],
#   'discount_allocations': []},
#  {'id': 14576518856930,
#   'admin_graphql_api_id': 'gid://shopify/LineItem/14576518856930',
#   'attributed_staffs': [],
#   'current_quantity': 1,
#   'fulfillable_quantity': 1,
#   'fulfillment_service': 'manual',
#   'fulfillment_status': None,
#   'gift_card': False,
#   'grams': 1361,
#   'name': 'Trolling Rudder & Weight Hanger Set',
#   'pre_tax_price': '12.00',
#   'pre_tax_price_set': {'shop_money': {'amount': '12.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#   'price': '12.00',
#   'price_set': {'shop_money': {'amount': '12.00', 'currency_code': 'USD'},
#    'presentment_money': {'amount': '12.00', 'currency_code': 'USD'}},
#   'product_exists': True,
#   'product_id': 8779852611810,
#   'properties': [],
#   'quantity': 1,
#   'requires_shipping': True,
#   'sku': 'Rudder Set',
#   'taxable': True,
#   'title': 'Trolling Rudder & Weight Hanger Set',
#   'total_discount': '0.00',
#   'total_discount_set': {'shop_money': {'amount': '0.00',
#     'currency_code': 'USD'},
#    'presentment_money': {'amount': '0.00', 'currency_code': 'USD'}},
#   'variant_id': 46217437413602,
#   'variant_inventory_management': 'shopify',
#   'variant_title': None,
#   'vendor': 'Catch America',
#   'tax_lines': [{'channel_liable': False,
#     'price': '0.03',
#     'price_set': {'shop_money': {'amount': '0.03', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.03', 'currency_code': 'USD'}},
#     'rate': 0.0025,
#     'title': 'Fresno County Tax'},
#    {'channel_liable': False,
#     'price': '0.12',
#     'price_set': {'shop_money': {'amount': '0.12', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.12', 'currency_code': 'USD'}},
#     'rate': 0.01,
#     'title': 'Fresno Co Local Tax Sl'},
#    {'channel_liable': False,
#     'price': '0.72',
#     'price_set': {'shop_money': {'amount': '0.72', 'currency_code': 'USD'},
#      'presentment_money': {'amount': '0.72', 'currency_code': 'USD'}},
#     'rate': 0.06,
#     'title': 'California State Tax'}],
#   'duties': [],
#   'discount_allocations': []}]

# %%
orders_df.columns
# Out:
# Index(['id', 'admin_graphql_api_id', 'app_id', 'browser_ip',
#        'buyer_accepts_marketing', 'cancel_reason', 'cancelled_at',
#        'cart_token', 'checkout_id', 'checkout_token',
#        ...
#        'shipping_address.latitude', 'shipping_address.longitude',
#        'shipping_address.name', 'shipping_address.country_code',
#        'shipping_address.province_code',
#        'customer.sms_marketing_consent.state',
#        'customer.sms_marketing_consent.opt_in_level',
#        'customer.sms_marketing_consent.consent_updated_at',
#        'customer.sms_marketing_consent.consent_collected_from',
#        'customer.email_marketing_consent'],
#       dtype='object', length=191)

# %%
orders_df['created_at']
# Out:
# 0      2025-02-20T09:19:23-08:00
# 1      2025-02-20T02:02:31-08:00
# 2      2025-02-19T20:11:52-08:00
# 3      2025-02-19T19:22:24-08:00
# 4      2025-02-19T15:45:28-08:00
#                  ...
# 245    2025-01-27T09:13:51-08:00
# 246    2025-01-27T07:59:18-08:00
# 247    2025-01-27T07:42:41-08:00
# 248    2025-01-27T05:21:19-08:00
# 249    2025-01-26T15:32:28-08:00
# Name: created_at, Length: 250, dtype: object

# %%
orders_df['processed_at']
# Out:
# 0      2025-02-20T09:19:21-08:00
# 1      2025-02-20T02:02:19-08:00
# 2      2025-02-19T20:11:49-08:00
# 3      2025-02-19T19:22:21-08:00
# 4      2025-02-19T15:45:23-08:00
#                  ...
# 245    2025-01-27T09:13:50-08:00
# 246    2025-01-27T07:59:17-08:00
# 247    2025-01-27T07:42:41-08:00
# 248    2025-01-27T05:21:15-08:00
# 249    2025-01-26T15:32:24-08:00
# Name: processed_at, Length: 250, dtype: object

# %%
orders_df['processed_at']
# Out:
# 0      2025-02-20T09:19:21-08:00
# 1      2025-02-20T02:02:19-08:00
# 2      2025-02-19T20:11:49-08:00
# 3      2025-02-19T19:22:21-08:00
# 4      2025-02-19T15:45:23-08:00
#                  ...
# 245    2025-01-27T09:13:50-08:00
# 246    2025-01-27T07:59:17-08:00
# 247    2025-01-27T07:42:41-08:00
# 248    2025-01-27T05:21:15-08:00
# 249    2025-01-26T15:32:24-08:00
# Name: processed_at, Length: 250, dtype: object
